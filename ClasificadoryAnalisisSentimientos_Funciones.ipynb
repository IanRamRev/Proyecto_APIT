# %%
import pandas
import numpy
import re
#Análisis de sentimientos
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
def separaTopico(topico, df): #Separa todos los encabezados de acuerdo a su tópico
    listTopic = []
    dataArr = numpy.asarray(df)
    for i in range(len(dataArr)):
        if(dataArr[i][1] == topico):
            listTopic.append(dataArr[i][0])
    return listTopic

# %%
def limpiaTexto(text):
    "List all the word tokens in a text."
    return re.findall('[a-zA-Z0-9\-áéíóúÁÉÍÓÚ#@]{3,254}', text.lower())

# %%
def cleanTildes(palabra):
    s = palabra
    replacements = (
        ("á", "a"),
        ("é", "e"),
        ("í", "i"),
        ("ó", "o"),
        ("ú", "u"),
    )
    
    for a, b in replacements:
        s = s.replace(a, b).replace(a.upper(), b.upper())
    
    return s

# %%
def limpiaPalabra(arrPalabras):
    raiz = []
    for i in range(len(arrPalabras)):
        #raiz.append(RaizSingular(cleanTildes(arrPalabras[i])))
        raiz.append(cleanTildes(arrPalabras[i]))
    
    return numpy.asarray(raiz, dtype=str)

# %%
def PalabrasTopico(listTopico): #Devuelve todas las palabras que aparecen en los titulares de las noticias 
    listHeadLines = []
    for i in range(len(listTopico)):
        #aux = nltk.word_tokenize(arrayTopico[i])
        aux = limpiaTexto(listTopico[i])
        #aux = limpiaPalabra()
        for j in range(len(aux)):
            aux2 = aux[j]
            listHeadLines.append(aux2)
            
    return numpy.asarray(listHeadLines)

# %%
def Probabilidad(palabrasTopico, palabrasUnicasTopico): #Devuelve un array con la ocurrencias de cada única del tópico
    Prob = numpy.zeros(len(palabrasUnicasTopico))
    for i in range(len(palabrasUnicasTopico)):
        Prob[i] = numpy.sum(palabrasTopico == palabrasUnicasTopico[i])
        Prob[i] = Prob[i] /len(palabrasTopico)
        
    return Prob

# %%
def Clasificador(arrayProbabilidades):
    indice = numpy.where(arrayProbabilidades == max(arrayProbabilidades))[0][0]
    #print("Max = ", max(arrayProbabilidades))
    if (indice == 0):
        #print("Covid")
        return 'covid'
    if (indice == 1):
        #print("Tecnología")
        return 'tecnologia'
    if (indice == 2):
        #print("Deportes")
        return 'deportes'
    if (indice == 3):
        #print("Economía")
        return 'economia'
    if (indice == 4):
        #print("Cultura")
        return 'cultura'
    return 'otros'

# %%
def MAP(tweet, palabrasCovid, AlfabetoCovid, palabrasTecn, AlfabetoTecn, palabrasDep, AlfabetoDep):
    T = nltk.word_tokenize(tweet)
    Proba = numpy.ones(5)

    #Covid
    for j in range(len(T)):
        aux = numpy.sum(palabrasCovid == T[j]) + 1
        Proba[0] *= (aux + 1) / (len(AlfabetoCovid) + aux)
    
    #Tecnologia
    for j in range(len(T)):
        aux = numpy.sum(palabrasTecn == T[j]) 
        Proba[1] *= (aux + 1) / (len(AlfabetoTecn) + aux)

    #Deportes
    for j in range(len(T)):
        aux = numpy.sum(palabrasDep == T[j]) + 1
        Proba[2] *= (aux + 1) / (len(AlfabetoDep) + aux)
        
    #Economía
    for j in range(len(T)):
        aux = numpy.sum(palabrasEcon == T[j]) + 1
        Proba[3] *= (aux + 1) / (len(AlfabetoEcon) + aux)
        
    #Economía
    for j in range(len(T)):
        aux = numpy.sum(palabrasCult == T[j]) + 1
        Proba[4] *= (aux + 1) / (len(AlfabetoCult) + aux)

    for p in range(len(Proba)):
        Proba[p] = Proba[p] * 1/5
        
    return Clasificador(Proba)

# %%
def preProcesamiento(listaTitulares):
    titulares = []
    for titular in listaTitulares:
        aux = limpiaTexto(titular)
        titulares.append(str.join(' ', aux))
    
    return titulares

# %%
nombres = ['Titular', 'Tópico']
dataTrain = pandas.read_csv('.//TitularesTrain//titulares.csv', names=nombres)
dataTrain = dataTrain.dropna()
dataTrain
# Out:
#                                                 Titular   Tópico
# 0     Cierran rastro de Mérida tras detectar 17 cont...    covid
# 2     El “peor escenario” para Tabasco eran 200 muer...    covid
# 4     Jalisco instalará espacios para enfermos no gr...    covid
# 6     Guerrero no está listo para iniciar la “nueva ...    covid
# 8     Reportan la muerte de 364 personas por covid-1...    covid
# ...                                                 ...      ...
# 7846  “El Cascanueces” de Disney: Cuento de hadas, m...  cultura
# 7848        Rock, blues y música alternativa en Sinaloa  cultura
# 7850   María Mercedes Coroy es “Malinche” en Canal Once  cultura
# 7852  “Motivos para el canto y la danza. Poesía del 68”  cultura
# 7854        Los pequeños mundos de Kandinsky en México   cultura
#
# [3926 rows x 2 columns]

# %%
palabrasCovid = limpiaPalabra(PalabrasTopico(separaTopico('covid', dataTrain)))
AlfabetoCovid = numpy.unique(palabrasCovid)
print(len(palabrasCovid))


palabrasTecn = limpiaPalabra(PalabrasTopico(separaTopico('tecnologia', dataTrain)))
AlfabetoTecn = numpy.unique(palabrasTecn)
#print(len(palabrasTecn))
#print(AlfabetoTecn)

palabrasDep = limpiaPalabra(PalabrasTopico(separaTopico('deportes', dataTrain)))
AlfabetoDep = numpy.unique(palabrasDep)

palabrasEcon = limpiaPalabra(PalabrasTopico(separaTopico('economia', dataTrain)))
AlfabetoEcon = numpy.unique(palabrasEcon)

palabrasCult = limpiaPalabra(PalabrasTopico(separaTopico('cultura', dataTrain)))
AlfabetoCult = numpy.unique(palabrasCult)

Alfabeto = numpy.concatenate((AlfabetoCovid, AlfabetoTecn, AlfabetoDep, AlfabetoEcon, AlfabetoCult))
#Alfabeto.shape
# Out:
# 9199

# %%
ProbaCov = Probabilidad(palabrasCovid, AlfabetoCovid)
print(ProbaCov)
ProbaTecn = Probabilidad(palabrasTecn, AlfabetoTecn)
ProbaDep = Probabilidad(palabrasDep, AlfabetoDep)
ProbaEcon = Probabilidad(palabrasEcon, AlfabetoEcon)
ProbaCult = Probabilidad(palabrasCult, AlfabetoCult)
# Out:
# [0.00010871 0.00021741 0.00054354 ... 0.00054354 0.00010871 0.00010871]

# %% [markdown]
# ## Análisis de sentimientos

# %%
lexicon = pandas.read_csv('SEL/SEL_UTF8.txt', sep='\t', names=['Palabra', 'PFA', 'Categoría'])
lexicon.drop(['Categoría'], axis='columns', inplace=True)
lexicon.info()

Palabras = numpy.array(lexicon.Palabra)
PFA = numpy.array(lexicon.PFA)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2037 entries, 0 to 2036
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Palabra  2037 non-null   object
#  1   PFA      2037 non-null   object
# dtypes: object(2)
# memory usage: 32.0+ KB

# %%
lista = []
for i in range(1, len(Palabras)):
    lista.append([Palabras[i], float(PFA[i])])
    
lexi = {a : b for a,b in lista}
lexi
# Out:
# {'abundancia': 0.83,
#  'acabalar': 0.396,
#  'acallar': 0.198,
#  'acatar': 0.198,
#  'acción': 0.397,
#  'aceptable': 0.594,
#  'aceptación': 0.696,
#  'acicate': 0.429,
#  'aclamación': 0.799,
#  'aclamar': 0.799,
#  'acogedor': 0.83,
#  'acoger': 0.729,
#  'acomodadamente': 0.729,
#  'acuciar': 0.264,
#  'acucioso': 0.232,
#  'adecuar': 0.331,
#  'adicto': 0.429,
#  'admirable': 0.73,
#  'admirablemente': 0.663,
#  'admiración': 0.764,
#  'admirar': 0.73,
#  'admitir': 0.53,
#  'adorable': 0.898,
#  'adorablemente': 0.865,
#  'adoración': 0.765,
#  'adorador': 0.664,
#  'adorar': 0.764,
#  'afable': 0.696,
#  'afán': 0.764,
#  'afectivo': 0.864,
#  'afecto': 0.899,
#  'afectuosamente': 0.966,
#  'afectuosidad': 0.932,
#  'afectuoso': 0.898,
#  'afervorizar': 0.731,
#  'afición': 0.729,
#  'aficionar': 0.595,
#  'afortunadamente': 0.831,
#  'afortunado': 0.932,
#  'agradable': 0.899,
#  'agradar': 0.798,
#  'agradecer': 0.763,
#  'agradecido': 0.764,
#  'agudeza': 0.331,
#  'aguzar': 0.199,
#  'ahínco': 0.73,
#  'ahíto': 0.564,
#  'airoso': 0.565,
#  'alabar': 0.53,
#  'alborozar': 0.899,
#  'alborozo': 0.899,
#  'alegrar': 0.966,
#  'alegre': 1.0,
#  'alegremente': 1.0,
#  'alegría': 1.0,
#  'alentar': 0.73,
#  'aliviar': 0.763,
#  'alivio': 0.763,
#  'allegar': 0.364,
#  'alma': 0.165,
#  'altivo': 0.33,
#  'altruismo': 0.529,
#  'alzar': 0.298,
#  'amabilidad': 0.728,
#  'amable': 0.762,
#  'amablemente': 0.762,
#  'amante': 0.731,
#  'amar': 0.899,
#  'amartelado': 0.966,
#  'amartelar': 0.731,
#  'amativo': 0.764,
#  'amatorio': 0.832,
#  'ambición': 0.429,
#  'ambicioso': 0.363,
#  'amigabilidad': 0.898,
#  'amigable': 0.898,
#  'amigablemente': 0.864,
#  'amigo': 0.898,
#  'amistad': 0.966,
#  'amistosamente': 0.898,
#  'amistoso': 0.966,
#  'amor': 0.966,
#  'amorosamente': 0.932,
#  'amorosidad': 0.898,
#  'amoroso': 0.898,
#  'amuleto': 0.398,
#  'anhelo': 0.297,
#  'animación': 0.562,
#  'animado': 0.865,
#  'animar': 0.797,
#  'ánimo': 0.099,
#  'animoso': 0.83,
#  'anticipar': 0.231,
#  'apaciguar': 0.298,
#  'apasionadamente': 0.663,
#  'apasionamiento': 0.696,
#  'apasionante': 0.798,
#  'apego': 0.597,
#  'apetecer': 0.363,
#  'aplaudir': 0.797,
#  'aplauso': 0.763,
#  'apreciar': 0.629,
#  'aprobación': 0.596,
#  'aprobar': 0.664,
#  'aprobatorio': 0.732,
#  'aquietar': 0.165,
#  'ardiente': 0.33,
#  'ardor': 0.265,
#  'armonía': 0.864,
#  'arreglar': 0.33,
#  'arrobo': 0.631,
#  'arrojo': 0.363,
#  'asombro': 0.966,
#  'atracción': 0.663,
#  'atractivo': 0.696,
#  'atraer': 0.631,
#  'atrayente': 0.53,
#  'atrayentemente': 0.497,
#  'autocomplacencia': 0.63,
#  'autorización': 0.397,
#  'autorrespeto': 0.598,
#  'autosatisfacción': 0.798,
#  'autosatisfecho': 0.796,
#  'autosuficiencia': 0.764,
#  'ávido': 0.198,
#  'avivar': 0.33,
#  'benefactor': 0.562,
#  'beneficencia': 0.596,
#  'beneficiado': 0.83,
#  'beneficiar': 0.729,
#  'beneficio': 0.898,
#  'beneficiosamente': 0.797,
#  'beneficioso': 0.864,
#  'benéfico': 0.831,
#  'beneplácito': 0.564,
#  'benévolamente': 0.462,
#  'benevolencia': 0.462,
#  'benevolente': 0.528,
#  'benévolo': 0.495,
#  'benignamente': 0.465,
#  'benigno': 0.465,
#  'bien': 0.798,
#  'bienandanza': 0.765,
#  'bienaventurado': 0.831,
#  'bienaventuranza': 0.63,
#  'bienestar': 0.932,
#  'bienhechor': 0.695,
#  'bienquerencia': 0.729,
#  'bienquerer': 0.762,
#  'bizbirondo': 0.899,
#  'blando': 0.198,
#  'blandura': 0.132,
#  'bondad': 0.696,
#  'bondadosamente': 0.696,
#  'bondadoso': 0.763,
#  'bonhomía': 0.462,
#  'brillante': 0.663,
#  'brío': 0.463,
#  'brioso': 0.463,
#  'bromear': 0.831,
#  'bueno': 0.898,
#  'bullanguero': 0.664,
#  'bullicioso': 0.664,
#  'burla': 0.364,
#  'burlar': 0.431,
#  'cabal': 0.264,
#  'calidez': 0.628,
#  'cálido': 0.43,
#  'caliente': 0.264,
#  'calmado': 0.231,
#  'calor': 0.099,
#  'calurosamente': 0.365,
#  'camaradería': 0.63,
#  'campante': 0.529,
#  'captivar': 0.43,
#  'capturar': 0.099,
#  'carcajada': 0.932,
#  'caridad': 0.63,
#  'cariño': 0.864,
#  'cariñosamente': 0.764,
#  'cariñoso': 0.83,
#  'caritativo': 0.63,
#  'cautivador': 0.628,
#  'cautivadoramente': 0.595,
#  'cautivar': 0.562,
#  'celebrar': 0.933,
#  'celo': 0.132,
#  'celosamente': 0.066,
#  'celoso': 0.033,
#  'chancear': 0.698,
#  'chanza': 0.598,
#  'chotear': 0.665,
#  'choteo': 0.564,
#  'chulear': 0.629,
#  'clemente': 0.264,
#  'cogida': 0.199,
#  'cogollo': 0.066,
#  'colmar': 0.165,
#  'colosal': 0.463,
#  'cómodamente': 0.629,
#  'comodidad': 0.662,
#  'cómodo': 0.695,
#  'compañerismo': 0.73,
#  'compasión': 0.63,
#  'compasivo': 0.63,
#  'compatibilidad': 0.496,
#  'compatible': 0.462,
#  'compatiblemente': 0.363,
#  'compensación': 0.331,
#  'complacencia': 0.629,
#  'complacer': 0.73,
#  'complacible': 0.595,
#  'complacido': 0.864,
#  'complaciente': 0.73,
#  'comprensivo': 0.562,
#  'concernir': 0.066,
#  'condescender': 0.363,
#  'condescendiente': 0.396,
#  'condimento': 0.099,
#  'condolencia': 0.796,
#  'confiado': 0.297,
#  'confirmación': 0.363,
#  'confirmar': 0.363,
#  'confort': 0.596,
#  'confortable': 0.663,
#  'confortablemente': 0.595,
#  'confortación': 0.529,
#  'confortador': 0.496,
#  'confortar': 0.529,
#  'confraternidad': 0.73,
#  'congeniar': 0.628,
#  'congraciar': 0.594,
#  'congratular': 0.731,
#  'conmiseración': 0.066,
#  'conmover': 0.165,
#  'conquista': 0.463,
#  'consenso': 0.33,
#  'consentimiento': 0.396,
#  'consideración': 0.396,
#  'considerar': 0.396,
#  'consolación': 0.397,
#  'consolador': 0.331,
#  'consolar': 0.397,
#  'consuelo': 0.43,
#  'consumar': 0.364,
#  'contemporizar': 0.165,
#  'contentar': 0.762,
#  'contento': 0.966,
#  'copiosidad': 0.562,
#  'copioso': 0.462,
#  'corazón': 0.33,
#  'cordial': 0.629,
#  'cordialidad': 0.663,
#  'cordialmente': 0.729,
#  'cortesía': 0.695,
#  'cosquillear': 0.764,
#  'cosquilleo': 0.764,
#  'crecer': 0.53,
#  'cuidar': 0.33,
#  'culminación': 0.398,
#  'culto': 0.264,
#  'cumplido': 0.529,
#  'cumplimentar': 0.364,
#  'cumplir': 0.496,
#  'decorativo': 0.363,
#  'dedicar': 0.462,
#  'deferencia': 0.495,
#  'deleitar': 0.796,
#  'deléitese': 0.695,
#  'delicadeza': 0.264,
#  'delicado': 0.066,
#  'delicia': 0.663,
#  'desagraviar': 0.231,
#  'desahogo': 0.363,
#  'desear': 0.033,
#  'desempeñar': 0.463,
#  'desempeño': 0.529,
#  'desenvoltura': 0.264,
#  'deseoso': 0.398,
#  'despenar': 0.297,
#  'despertar': 0.198,
#  'despreocupación': 0.563,
#  'devoción': 0.497,
#  'devoto': 0.463,
#  'dicha': 0.731,
#  'dichosamente': 0.764,
#  'dichoso': 0.832,
#  'dignificar': 0.462,
#  'dilección': 0.563,
#  'disfrutar': 0.83,
#  'disfrute': 0.898,
#  'divertidamente': 0.966,
#  'divertidísimamente': 1.0,
#  'divertido': 1.0,
#  'divertir': 0.966,
#  'divinizar': 0.363,
#  'divino': 0.563,
#  'donaire': 0.396,
#  'dulce': 0.562,
#  'dulzura': 0.663,
#  'edificante': 0.497,
#  'edificar': 0.363,
#  'efusión': 0.497,
#  'efusivamente': 0.73,
#  'efusivo': 0.764,
#  'ejemplo': 0.231,
#  'elección': 0.264,
#  'elegante': 0.231,
#  'elevar': 0.165,
#  'elogio': 0.463,
#  'embebecer': 0.596,
#  'embelesar': 0.596,
#  'embeleso': 0.497,
#  'embobar': 0.099,
#  'emborrachar': 0.562,
#  'embriagar': 0.562,
#  'embromar': 0.595,
#  'embrujar': 0.132,
#  'embrujo': 0.099,
#  'emoción': 0.798,
#  'emocionante': 0.831,
#  'emocionar': 0.831,
#  'emotivo': 0.763,
#  'empatía': 0.462,
#  'empático': 0.396,
#  'empeño': 0.396,
#  'enaltecer': 0.496,
#  'enamoramiento': 0.864,
#  'enamorar': 0.831,
#  'encalmar': 0.198,
#  'encantado': 0.495,
#  'encantador': 0.695,
#  'encanto': 0.562,
#  'encomiar': 0.529,
#  'endiosar': 0.396,
#  'energía': 0.496,
#  'engrandecer': 0.53,
#  'ennoblecer': 0.463,
#  'enorgullecer': 0.797,
#  'enternecimiento': 0.564,
#  'entraña': 0.099,
#  'entrañable': 0.298,
#  'entrar': 0.165,
#  'entregar': 0.231,
#  'entusiasmado': 0.864,
#  'entusiasmar': 0.83,
#  'entusiasmo': 0.864,
#  'entusiasta': 0.864,
#  'erótico': 0.529,
#  'espectacular': 0.563,
#  'esperanza': 0.495,
#  'esperanzado': 0.496,
#  'espléndido': 0.696,
#  'estimar': 0.629,
#  'estimulante': 0.497,
#  'estimular': 0.496,
#  'estremecer': 0.628,
#  'estupendo': 0.698,
#  'euforia': 0.663,
#  'eufórico': 0.663,
#  'euforizante': 0.663,
#  'exaltar': 0.563,
#  'excelente': 0.763,
#  'excitante': 0.864,
#  'excitar': 0.265,
#  'exhortar': 0.165,
#  'éxito': 0.864,
#  'expansivo': 0.363,
#  'expectación': 0.264,
#  'expectativa': 0.297,
#  'explosión': 0.198,
#  'expresión': 0.297,
#  'extasiante': 0.796,
#  'extasiar': 0.762,
#  'extenso': 0.099,
#  'exuberante': 0.396,
#  'exuberantemente': 0.363,
#  'exultar': 0.796,
#  'familiar': 0.529,
#  'familiaridad': 0.629,
#  'fantasía': 0.596,
#  'fascinación': 0.898,
#  'fascinado': 0.898,
#  'fascinante': 0.73,
#  'fascinar': 0.731,
#  'fasto': 0.265,
#  'fastuoso': 0.363,
#  'fausto': 0.363,
#  'favor': 0.33,
#  'favorable': 0.596,
#  'favorablemente': 0.563,
#  'favorecedor': 0.562,
#  'favorecimiento': 0.562,
#  'felicidad': 1.0,
#  'felicitar': 0.831,
#  'feliz': 0.966,
#  'felizmente': 0.966,
#  'feraz': 0.33,
#  'fervor': 0.597,
#  'fervoroso': 0.564,
#  'festivo': 0.729,
#  'fetiche': 0.265,
#  'fibra': 0.0,
#  'fidelidad': 0.43,
#  'fiebre': 0.132,
#  'fiel': 0.463,
#  'fiesta': 0.83,
#  'fijar': 0.132,
#  'filantropo': 0.463,
#  'final': 0.198,
#  'fino': 0.198,
#  'flechar': 0.297,
#  'florecer': 0.595,
#  'fogosidad': 0.561,
#  'fraternidad': 0.595,
#  'fraternizar': 0.529,
#  'furor': 0.566,
#  'gala': 0.297,
#  'gana': 0.463,
#  'ganar': 0.764,
#  'generosidad': 0.628,
#  'generoso': 0.628,
#  'genial': 0.864,
#  'gloria': 0.797,
#  'gloriar': 0.562,
#  'glorificar': 0.529,
#  'goce': 0.763,
#  'gozar': 0.831,
#  'gozo': 0.831,
#  'gozosamente': 0.765,
#  'gozoso': 0.798,
#  'gracia': 0.597,
#  'gracioso': 0.83,
#  'grande': 0.396,
#  'grandioso': 0.63,
#  'gratificador': 0.664,
#  'gratificante': 0.697,
#  'gratificar': 0.598,
#  'gratis': 0.563,
#  'grato': 0.663,
#  'guasa': 0.429,
#  'gustar': 0.596,
#  'gusto': 0.629,
#  'gustoso': 0.762,
#  'halagar': 0.563,
#  'halagüeño': 0.396,
#  'hartar': 0.898,
#  'hechizar': 0.231,
#  'hechizo': 0.297,
#  'hermandad': 0.561,
#  'hilarante': 0.63,
#  'hilarantemente': 0.597,
#  'hilaridad': 0.664,
#  'hipnotizar': 0.165,
#  'holgura': 0.265,
#  'honorable': 0.53,
#  'honrar': 0.396,
#  'honrosamente': 0.429,
#  'hospitalario': 0.563,
#  'hospitalidad': 0.629,
#  'humanidad': 0.33,
#  'humanitarismo': 0.264,
#  'humor': 0.265,
#  'identificar': 0.132,
#  'idilio': 0.396,
#  'ilusionadamente': 0.462,
#  'ilusionar': 0.495,
#  'impactar': 0.732,
#  'ímpetu': 0.529,
#  'impetuosidad': 0.463,
#  'impresionar': 0.865,
#  'impulsar': 0.363,
#  'inclinación': 0.099,
#  'inmortalizar': 0.198,
#  'inspirar': 0.53,
#  'interés': 0.33,
#  'intoxicante': 0.066,
#  'jacarero': 0.664,
#  'jarana': 0.365,
#  'jocoso': 0.564,
#  'jocundo': 0.763,
#  'jovial': 0.73,
#  'júbilo': 0.83,
#  'jubilosamente': 0.73,
#  'jubiloso': 0.731,
#  'juerga': 0.531,
#  'laudable': 0.363,
#  'leal': 0.463,
#  'lealtad': 0.463,
#  'ledamente': 0.731,
#  'lenificar': 0.265,
#  'lenizar': 0.199,
#  'levantar': 0.198,
#  'libre': 0.696,
#  'lisonjero': 0.73,
#  'llenar': 0.33,
#  'loable': 0.33,
#  'lograr': 0.663,
#  'lucro': 0.198,
#  'macanudo': 0.73,
#  'magia': 0.561,
#  'magnetizar': 0.132,
#  'magnifíco': 0.798,
#  'magno': 0.365,
#  'majo': 0.429,
#  'maravillar': 0.898,
#  'maravillosamente': 0.932,
#  'mejorar': 0.529,
#  'meloso': 0.396,
#  'miramiento': 0.231,
#  'mirar': 0.165,
#  'misericordia': 0.198,
#  'mitigar': 0.165,
#  'mollar': 0.099,
#  'motivar': 0.597,
#  'mover': 0.099,
#  'oferta': 0.165,
#  'opimo': 0.396,
#  'opíparo': 0.396,
#  'orgullo': 0.596,
#  'orgullosamente': 0.697,
#  'orgulloso': 0.531,
#  'ovación': 0.796,
#  'ovacionar': 0.663,
#  'pacificar': 0.332,
#  'paladear': 0.33,
#  'palmas': 0.496,
#  'parranda': 0.628,
#  'pasión': 0.763,
#  'paz': 0.63,
#  'piadoso': 0.363,
#  'piedad': 0.297,
#  'placentero': 0.796,
#  'placer': 0.864,
#  'pleitesía': 0.199,
#  'preferencia': 0.397,
#  'prerrogativa': 0.231,
#  'preservar': 0.165,
#  'presumir': 0.264,
#  'prever': 0.264,
#  'privilegio': 0.463,
#  'probar': 0.198,
#  'profusión': 0.198,
#  'propiciar': 0.264,
#  'propicio': 0.33,
#  'próspero': 0.762,
#  'protectoramente': 0.231,
#  'proteger': 0.231,
#  'provecho': 0.463,
#  'provechoso': 0.53,
#  'providencial': 0.231,
#  'pujanza': 0.165,
#  'querer': 0.63,
#  'quietud': 0.198,
#  'quillotrar': 0.363,
#  'radiante': 0.53,
#  'ratificar': 0.132,
#  'realización': 0.364,
#  'realizar': 0.231,
#  'recoger': 0.132,
#  'recogimiento': 0.132,
#  'recomendar': 0.297,
#  'recompensa': 0.629,
#  'reconfortante': 0.797,
#  'reconfortar': 0.696,
#  'recrear': 0.497,
#  'refocilar': 0.563,
#  'regalo': 0.764,
#  'regocijadamente': 0.763,
#  'regocijar': 0.696,
#  'regocijo': 0.764,
#  'regodear': 0.43,
#  'regodeo': 0.363,
#  'reidor': 0.798,
#  'relamer': 0.396,
#  'reparación': 0.198,
#  'reproducir': 0.264,
#  'respetar': 0.531,
#  'respeto': 0.497,
#  'respetuoso': 0.531,
#  'resplandecer': 0.598,
#  'reverencia': 0.364,
#  'risa': 0.932,
#  'risueño': 0.932,
#  'romántico': 0.63,
#  'saber': 0.297,
#  'saborear': 0.43,
#  'saciar': 0.464,
#  'saciedad': 0.464,
#  'sandunga': 0.629,
#  'satisfacción': 0.864,
#  'satisfacer': 0.83,
#  'satisfacible': 0.763,
#  'satisfactoriamente': 0.831,
#  'satisfactorio': 0.831,
#  'satisfecho': 0.864,
#  'seducción': 0.529,
#  'seducir': 0.496,
#  'seductivo': 0.596,
#  'seguro': 0.465,
#  'selecto': 0.364,
#  'serenar': 0.231,
#  'sereno': 0.198,
#  'simpatía': 0.797,
#  'simpático': 0.83,
#  'simpatizar': 0.83,
#  'sincero': 0.397,
#  'soberbio': 0.165,
#  'sociable': 0.53,
#  'solaz': 0.198,
#  'solazar': 0.264,
#  'solidaridad': 0.464,
#  'sonriente': 0.966,
#  'sortilegio': 0.264,
#  'sosegar': 0.264,
#  'suave': 0.231,
#  'suavidad': 0.231,
#  'subyugar': 0.099,
#  'superabundancia': 0.564,
#  'superabundante': 0.63,
#  'suspender': 0.099,
#  'terneza': 0.397,
#  'ternura': 0.529,
#  'tesón': 0.132,
#  'tiernamente': 0.53,
#  'tierno': 0.53,
#  'tranquilizar': 0.364,
#  'tranquilo': 0.397,
#  'transportar': 0.199,
#  'tratable': 0.297,
#  'triunfador': 0.796,
#  'triunfal': 0.796,
#  'triunfalmente': 0.728,
#  'triunfante': 0.796,
#  'triunfantemente': 0.796,
#  'triunfar': 0.83,
#  'triunfo': 0.864,
#  'tuitivo': 0.298,
#  'ubérrimo': 0.165,
#  'ufanamente': 0.132,
#  'ufanía': 0.099,
#  'ufano': 0.132,
#  'ultimar': 0.165,
#  'unción': 0.231,
#  'unión': 0.297,
#  'útil': 0.429,
#  'valía': 0.43,
#  'valimiento': 0.331,
#  'valorar': 0.497,
#  'vehemencia': 0.331,
#  'vehemente': 0.331,
#  'vencedor': 0.696,
#  'veneración': 0.496,
#  'venerar': 0.463,
#  'ventajosamente': 0.297,
#  'ventajoso': 0.33,
#  'venturosamente': 0.53,
#  'venturoso': 0.63,
#  'victorear': 0.563,
#  'victoria': 0.763,
#  'victorioso': 0.797,
#  'vigor': 0.497,
#  'vítor': 0.297,
#  'vitorear': 0.297,
#  'vivaz': 0.563,
#  'viveza': 0.629,
#  'vivificar': 0.563,
#  'vivir': 0.63,
#  'abominable': 0.797,
#  'abominación': 0.464,
#  'abominar': 0.797,
#  'aborrecer': 0.966,
#  'aborrecible': 0.966,
#  'aborreciblemente': 0.629,
#  'aborrecimiento': 0.663,
#  'abusar': 0.697,
#  'acometedor': 0.463,
#  'acometer': 0.497,
#  'acometiente': 0.464,
#  'acometimiento': 0.431,
#  'acometividad': 0.397,
#  'acosar': 0.465,
#  'acribillar': 0.666,
#  'acrimonia': 0.363,
#  'acritud': 0.33,
#  'adversario': 0.363,
#  'aferrar': 0.265,
#  'afrenta': 0.53,
#  'agarrar': 0.231,
#  'agobiar': 0.697,
#  'agobio': 0.231,
#  'agravamiento': 0.397,
#  'agravante': 0.463,
#  'agravar': 0.43,
#  'agraviar': 0.331,
#  'agravio': 0.43,
#  'agresividad': 0.831,
#  'agresivo': 0.865,
#  'agresor': 0.83,
#  'agriado': 0.497,
#  'airadamente': 0.596,
#  'airamiento': 0.563,
#  'airar': 0.663,
#  'alevosía': 0.396,
#  'altivez': 0.264,
#  'amargar': 0.363,
#  'amargo': 0.264,
#  'amargor': 0.132,
#  'amohinar': 0.599,
#  'amoscamiento': 0.397,
#  'animadversión': 0.497,
#  'animosidad': 0.132,
#  'antagónico': 0.199,
#  'antagonismo': 0.364,
#  'antipatía': 0.662,
#  'antipático': 0.728,
#  'apesadumbrar': 0.495,
#  'arrebatamiento': 0.63,
#  'arrebato': 0.497,
#  'arrojar': 0.496,
#  'asar': 0.165,
#  'asediar': 0.364,
#  'aspereza': 0.298,
#  'asurar': 0.398,
#  'atacar': 0.832,
#  'ataque': 0.899,
#  'atizar': 0.465,
#  'atormentar': 0.53,
#  'atosigar': 0.563,
#  'atrabiliario': 0.664,
#  'atrocidad': 0.331,
#  'atropellar': 0.398,
#  'atropello': 0.397,
#  'atroz': 0.696,
#  'atufar': 0.398,
#  'azuzar': 0.264,
#  'baquetear': 0.365,
#  'barbaridad': 0.364,
#  'batallar': 0.463,
#  'belicosidad': 0.53,
#  'belicoso': 0.53,
#  'beligerante': 0.396,
#  'berrinche': 0.629,
#  'bilis': 0.532,
#  'bochinche': 0.363,
#  'bravo': 0.563,
#  'bufar': 0.532,
#  'cabrear': 0.597,
#  'cargoso': 0.363,
#  'celos': 0.63,
#  'chalar': 0.232,
#  'chinche': 0.396,
#  'cinismo': 0.298,
#  'cizañar': 0.463,
#  'cocolía': 0.53,
#  'cólera': 0.73,
#  'coléricamente': 0.83,
#  'colérico': 0.762,
#  'concitar': 0.363,
#  'contrariar': 0.463,
#  'contrariedad': 0.331,
#  'convulsión': 0.33,
#  'coraje': 0.899,
#  'corajudo': 0.831,
#  'corroer': 0.297,
#  'crispar': 0.43,
#  'crucificar': 0.198,
#  'cuenta': 0.0,
#  'decepción': 0.898,
#  'decepcionar': 0.898,
#  'demente': 0.364,
#  'demonio': 0.63,
#  'denigrar': 0.496,
#  'desaforo': 0.132,
#  'desagradable': 0.898,
#  'desagradar': 0.628,
#  'desagrado': 0.798,
#  'desairar': 0.53,
#  'desaire': 0.53,
#  'desaprobar': 0.463,
#  'desazón': 0.165,
#  'descaro': 0.563,
#  'descontentar': 0.562,
#  'descontento': 0.397,
#  'desdén': 0.463,
#  'desdeñar': 0.397,
#  'deseable': 0.099,
#  'desesperante': 0.496,
#  'desmán': 0.529,
#  'desorden': 0.496,
#  'despecho': 0.662,
#  'desplacer': 0.595,
#  'despreciar': 0.696,
#  'desprecio': 0.696,
#  'desquiciante': 0.83,
#  'desquiciar': 0.898,
#  'destemplar': 0.397,
#  'desvarío': 0.231,
#  'detestable': 0.966,
#  'detestablemente': 0.932,
#  'detestación': 0.932,
#  'detestar': 0.663,
#  'diantre': 0.432,
#  'discordia': 0.562,
#  'discrepancia': 0.33,
#  'disgustar': 0.595,
#  'disgusto': 0.595,
#  'displacer': 0.463,
#  'disputa': 0.763,
#  'doloso': 0.397,
#  'embestir': 0.564,
#  'embravecer': 0.731,
#  'emperrarse': 0.764,
#  'emponzoñar': 0.665,
#  'enajenación': 0.397,
#  'enajenar': 0.33,
#  'encabritar': 0.83,
#  'encalabrinar': 0.563,
#  'encocorar': 0.664,
#  'encolerizar': 0.83,
#  'enconar': 0.331,
#  'encono': 0.298,
#  'encorajinar': 0.831,
#  'endemoniar': 0.83,
#  'enemigo': 0.83,
#  'enemistad': 0.831,
#  'enemistoso': 0.797,
#  'enérgico': 0.431,
#  'enfadado': 0.932,
#  'enfadar': 0.898,
#  'enfado': 0.898,
#  'enfadoso': 0.864,
#  'enfierecido': 0.864,
#  'enfurecer': 0.932,
#  'enfurecimiento': 0.864,
#  'enfurruñamiento': 0.696,
#  'enganza': 0.596,
#  'engativamente': 0.563,
#  'engorro': 0.264,
#  'engorroso': 0.264,
#  'enloquecedor': 0.463,
#  'enloquecer': 0.463,
#  'enloquecimiento': 0.43,
#  'enojadizo': 0.864,
#  'enojado': 0.966,
#  'enojamiento': 0.898,
#  'enojar': 0.966,
#  'enojo': 0.966,
#  'enojosamente': 0.932,
#  'enojoso': 0.932,
#  'enrabiar': 0.966,
#  'enrabietar': 0.932,
#  'ensañamiento': 0.596,
#  'ensañar': 0.596,
#  'entuerto': 0.298,
#  'envenenar': 0.364,
#  'envidia': 0.496,
#  'envidioso': 0.462,
#  'escandalizar': 0.297,
#  'escándalo': 0.198,
#  'estafar': 0.43,
#  'estorbar': 0.331,
#  'estorbo': 0.331,
#  'estropear': 0.53,
#  'exabrupto': 0.663,
#  'exacerbación': 0.729,
#  'exacerbante': 0.729,
#  'exacerbar': 0.73,
#  'exagerar': 0.33,
#  'exasperación': 0.63,
#  'exasperante': 0.696,
#  'exasperar': 0.696,
#  'excandecencia': 0.731,
#  'exceso': 0.198,
#  'execrar': 0.299,
#  'fastidiado': 0.729,
#  'fastidiante': 0.729,
#  'fastidiar': 0.53,
#  'fastidio': 0.597,
#  'fastidioso': 0.762,
#  'feo': 0.297,
#  'fiera': 0.53,
#  'fracaso': 0.43,
#  'frenético': 0.496,
#  'fruncir': 0.496,
#  'furia': 0.866,
#  'furibundamente': 0.831,
#  'furibundo': 0.831,
#  'furiosamente': 0.933,
#  'furioso': 0.833,
#  'fustigar': 0.397,
#  'genio': 0.43,
#  'grima': 0.629,
#  'gruñón': 0.763,
#  'guerra': 0.832,
#  'hastiar': 0.596,
#  'hastioso': 0.629,
#  'hiel': 0.595,
#  'hostigador': 0.563,
#  'hostigar': 0.53,
#  'hostil': 0.498,
#  'hostilidad': 0.564,
#  'hostilizar': 0.564,
#  'impacientar': 0.529,
#  'importunar': 0.496,
#  'importuno': 0.462,
#  'improperio': 0.429,
#  'inaguantable': 0.563,
#  'incomodar': 0.529,
#  'incomodidad': 0.463,
#  'incontrol': 0.363,
#  'incordiar': 0.531,
#  'incordio': 0.531,
#  'indignación': 0.563,
#  'indignado': 0.597,
#  'indignante': 0.597,
#  'indignar': 0.597,
#  'infamar': 0.43,
#  'inicuo': 0.364,
#  'injuriar': 0.597,
#  'inquina': 0.463,
#  'insatisfecho': 0.331,
#  'insidia': 0.43,
#  'insultar': 0.832,
#  'insulto': 0.764,
#  'intratable': 0.696,
#  'ira': 0.966,
#  'iracundia': 0.697,
#  'iracundo': 0.797,
#  'irascible': 0.731,
#  'irritabilidad': 0.864,
#  'irritable': 0.898,
#  'irritación': 0.796,
#  'irritado': 0.83,
#  'irritante': 0.83,
#  'irritar': 0.796,
#  'jaqueca': 0.528,
#  'jorobar': 0.697,
#  'latoso': 0.63,
#  'loco': 0.396,
#  'lrascible': 0.463,
#  'majadero': 0.63,
#  'mal ': 0.53,
#  'maldición': 0.664,
#  'maldito': 0.264,
#  'malévolo': 0.595,
#  'malhumor': 0.764,
#  'malhumorado': 0.797,
#  'malicia': 0.595,
#  'maliciar': 0.562,
#  'malignidad': 0.462,
#  'maligno': 0.764,
#  'malo': 0.265,
#  'malpensado': 0.33,
#  'malquerencia': 0.396,
#  'malvadamente': 0.495,
#  'malvado': 0.798,
#  'manía': 0.264,
#  'martirio': 0.298,
#  'martirizar': 0.397,
#  'misoneísmo': 0.099,
#  'mohíno': 0.498,
#  'molestar': 0.132,
#  'molesto': 0.696,
#  'molestoso': 0.696,
#  'mortificar': 0.397,
#  'mosconear': 0.332,
#  'nervioso': 0.165,
#  'obstaculizar': 0.231,
#  'odiar': 0.932,
#  'odio': 0.932,
#  'ofensa': 0.764,
#  'ofensividad': 0.729,
#  'ofensivo': 0.697,
#  'ojeriza': 0.429,
#  'opresión': 0.264,
#  'pelea': 0.73,
#  'pendenciar': 0.463,
#  'pendenciero': 0.463,
#  'pernicioso': 0.396,
#  'perseguir': 0.231,
#  'pesado': 0.264,
#  'pestilente': 0.864,
#  'picar': 0.132,
#  'pique': 0.429,
#  'prender': 0.231,
#  'provocación': 0.561,
#  'provocar': 0.528,
#  'puchero': 0.231,
#  'pugna': 0.198,
#  'pugnante': 0.165,
#  'punzar': 0.165,
#  'quejar': 0.561,
#  'querellar': 0.529,
#  'quicio': 0.596,
#  'rabia': 0.763,
#  'rabiosamente': 0.864,
#  'rabioso': 0.797,
#  'regañadientes': 0.728,
#  'regaño': 0.729,
#  ...}

# %%
SIA = SentimentIntensityAnalyzer()
SIA.lexicon.update(lexi)
